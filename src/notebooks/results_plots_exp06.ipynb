# %%
import pandas as pd
import matplotlib.pyplot as plt
import sns
import numpy as np

# %%
df_ml = pd.read_csv('../artifacts/results_ml_models.csv')
df_cnn = pd.read_csv('../artifacts/results_cnn_models.csv')
df_trans = pd.read_csv('../artifacts/results_Transformer_models.csv')

# %% [markdown]
# # CNN Models

# %%
df_cnn["label"] = df_cnn.model  + "| subjc: " + df_cnn.subject.astype(str)  
df_cnn.groupby(['model','subject']).mean()
# Out:
#                         acc_test  Precision    Recall  F1_score       auc  \
# model          subject
# DeepConvNet    10       0.277778   0.355556  0.277778  0.298413  0.843750
#                11       0.222222   0.541667  0.222222  0.297619  0.609375
#                12       0.500000   0.488889  0.500000  0.490643  0.250000
#                13       0.444444   0.373737  0.444444  0.405556  0.281250
#                14       0.388889   0.398148  0.388889  0.355556  0.609375
#                15       0.611111   0.611111  0.611111  0.592593  0.734375
#                16       0.277778   0.322751  0.277778  0.294444  0.312500
#                17       0.444444   0.470238  0.444444  0.435606  0.656250
#                18       0.777778   0.851852  0.777778  0.785648  0.687500
#                19       0.333333   0.340278  0.333333  0.331155  0.765625
# EEGNet         10       0.500000   0.583333  0.500000  0.532738  0.796875
#                11       0.166667   0.238095  0.166667  0.163580  0.390625
#                12       0.388889   0.351852  0.388889  0.361111  0.390625
#                13       0.555556   0.451852  0.555556  0.494347  0.250000
#                14       0.333333   0.394180  0.333333  0.356944  0.578125
#                15       0.666667   0.703704  0.666667  0.677778  0.593750
#                16       0.222222   0.337037  0.222222  0.258730  0.437500
#                17       0.555556   0.375817  0.555556  0.420228  0.468750
#                18       0.833333   0.870370  0.833333  0.840741  0.781250
#                19       0.444444   0.387037  0.444444  0.412865  0.625000
# HopefullNet    10       0.388889   0.402778  0.388889  0.389978  0.718750
#                11       0.277778   0.388889  0.277778  0.305556  0.437500
#                12       0.555556   0.611111  0.555556  0.538360  0.312500
#                13       0.500000   0.474747  0.500000  0.474074  0.531250
#                14       0.333333   0.305556  0.333333  0.314815  0.421875
#                15       0.611111   0.547980  0.611111  0.572222  0.937500
#                16       0.388889   0.388889  0.388889  0.388889  0.421875
#                17       0.555556   0.480159  0.555556  0.488567  0.375000
#                18       0.777778   0.705387  0.777778  0.727778  0.765625
#                19       0.555556   0.611111  0.555556  0.538360  0.515625
# ShallowConvNet 10       0.166667   0.222222  0.166667  0.174603  0.343750
#                11       0.555556   0.466667  0.555556  0.458333  0.406250
#                12       0.500000   0.459259  0.500000  0.475000  0.562500
#                13       0.555556   0.411111  0.555556  0.449074  0.406250
#                14       0.555556   0.432540  0.555556  0.465378  0.609375
#                15       0.555556   0.488889  0.555556  0.481481  0.656250
#                16       0.333333   0.300000  0.333333  0.315789  0.250000
#                17       0.611111   0.432540  0.611111  0.502415  0.687500
#                18       0.666667   0.761111  0.666667  0.671053  0.750000
#                19       0.500000   0.435897  0.500000  0.451515  0.343750
#
#                            kappa  mathew_coef  acc_train   acc_val
# model          subject
# DeepConvNet    10       0.037037     0.039154   0.905556  0.444444
#                11       0.041825     0.045963   0.936111  0.166667
#                12       0.250000     0.252513   0.975000  0.333333
#                13       0.142857     0.146847   0.977778  0.444444
#                14       0.195122     0.220221   0.986111  0.388889
#                15       0.434978     0.440927   0.986111  0.388889
#                16       0.012658     0.013107   0.952778  0.166667
#                17       0.220779     0.238484   0.958333  0.444444
#                18       0.694915     0.710496   0.997222  0.444444
#                19       0.060870     0.061957   0.966667  0.666667
# EEGNet         10       0.310638     0.321664   0.783333  0.333333
#                11      -0.022727    -0.025994   0.755556  0.333333
#                12       0.116071     0.122778   0.825000  0.388889
#                13       0.336406     0.348188   0.861111  0.500000
#                14       0.088608     0.090601   0.833333  0.333333
#                15       0.515695     0.518018   0.863889  0.500000
#                16      -0.016129    -0.016912   0.722222  0.333333
#                17       0.147929     0.287756   0.819444  0.500000
#                18       0.756757     0.760189   0.875000  0.666667
#                19       0.170507     0.173018   0.830556  0.611111
# HopefullNet    10       0.135371     0.138398   0.927778  0.611111
#                11      -0.044643    -0.046990   0.938889  0.277778
#                12       0.290640     0.303704   0.950000  0.277778
#                13       0.221154     0.225166   0.969444  0.444444
#                14       0.040000     0.041291   0.963889  0.388889
#                15       0.397129     0.404133   0.972222  0.555556
#                16       0.104072     0.104550   0.955556  0.444444
#                17       0.234043     0.267360   0.972222  0.444444
#                18       0.655502     0.674198   0.994444  0.555556
#                19       0.290640     0.305507   0.975000  0.611111
# ShallowConvNet 10      -0.088710    -0.095310   0.975000  0.388889
#                11       0.208791     0.263053   0.988889  0.500000
#                12       0.263636     0.269911   0.997222  0.500000
#                13       0.208791     0.260298   1.000000  0.444444
#                14       0.234043     0.267360   0.994444  0.388889
#                15       0.213115     0.267148   0.997222  0.611111
#                16       0.009174     0.009539   1.000000  0.444444
#                17       0.329787     0.379861   0.980556  0.444444
#                18       0.502304     0.514724   1.000000  0.611111
#                19       0.169231     0.183299   1.000000  0.833333

# %%
df_cnn.head()
# Out:
#    acc_test  Precision    Recall  F1_score       auc     kappa  mathew_coef  \
# 0  0.833333   0.870370  0.833333  0.840741  0.781250  0.756757     0.760189
# 1  0.777778   0.705387  0.777778  0.727778  0.765625  0.655502     0.674198
# 2  0.777778   0.851852  0.777778  0.785648  0.687500  0.694915     0.710496
# 3  0.666667   0.761111  0.666667  0.671053  0.750000  0.502304     0.514724
# 4  0.666667   0.703704  0.666667  0.677778  0.593750  0.515695     0.518018
#
#        model_name           model          dataset  subject  acc_train  \
# 0          EEGNet          EEGNet  Motor Imaginary       18   0.875000
# 1     HopefullNet     HopefullNet  Motor Imaginary       18   0.994444
# 2     DeepConvNet     DeepConvNet  Motor Imaginary       18   0.997222
# 3  ShallowConvNet  ShallowConvNet  Motor Imaginary       18   1.000000
# 4          EEGNet          EEGNet  Motor Imaginary       15   0.863889
#
#     acc_val                      label
# 0  0.666667          EEGNet| subjc: 18
# 1  0.555556     HopefullNet| subjc: 18
# 2  0.444444     DeepConvNet| subjc: 18
# 3  0.611111  ShallowConvNet| subjc: 18
# 4  0.500000          EEGNet| subjc: 15

# %%
top_1 = df_cnn.iloc[:,-3]
top_3 = df_cnn.iloc[:,-2]
top_5 = df_cnn.iloc[:,0]
xlabels = df_cnn.iloc[:,-1]
N = len(df_cnn.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars
fig, ax = plt.subplots(figsize=(24,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
rects2 = ax.bar(ind + width, top_3, width, color='#f5c767')
rects3 = ax.bar(ind + 2*width, top_5, width, color='#7a61ba')
ax.set_xticks(ind + width)
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)
ax.set_title('Accuracy for CNNs models | Inter-subject')
ax.legend((rects1[0], rects2[0],rects3[0]),('Acc Train', 'Acc Validation','Acc Test'),bbox_to_anchor=(1.13, 1.01))
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)
labelvalue(rects2)
labelvalue(rects3)
plt.savefig('../artifacts/barplot_cnn.png',dpi=200, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Machine Learning Models

# %%
df_ml['label'] = df_ml.pipeline.replace("time domain features -> wavelet", "TmFq + Wvl") +' + '+ df_ml.model_name
df_ml["label"] = df_ml.label  + "| subjc: " + df_ml.subject.astype(str)  
df_ml.groupby(['label','subject']).mean()
# Out:
#                                      cross_val_score  Accuracy  Precision  \
# label                       subject
# PCA + KNN| subjc: 10        10                 0.672  0.222222   0.286045
# PCA + KNN| subjc: 11        11                 0.733  0.222222   0.280704
# PCA + KNN| subjc: 12        12                 0.750  0.305556   0.423611
# PCA + KNN| subjc: 13        13                 0.839  0.333333   0.444577
# PCA + KNN| subjc: 14        14                 0.836  0.361111   0.434524
# PCA + KNN| subjc: 15        15                 0.867  0.472222   0.530784
# PCA + KNN| subjc: 16        16                 0.736  0.138889   0.557485
# PCA + KNN| subjc: 17        17                 0.792  0.388889   0.509524
# PCA + KNN| subjc: 18        18                 0.850  0.527778   0.614779
# PCA + KNN| subjc: 19        19                 0.864  0.222222   0.265432
# PCA + SVM| subjc: 10        10                 0.881  0.194444   0.204861
# PCA + SVM| subjc: 11        11                 0.914  0.444444   0.302579
# PCA + SVM| subjc: 12        12                 0.942  0.333333   0.358796
# PCA + SVM| subjc: 13        13                 0.947  0.555556   0.484127
# PCA + SVM| subjc: 14        14                 0.903  0.444444   0.331349
# PCA + SVM| subjc: 15        15                 0.961  0.583333   0.519962
# PCA + SVM| subjc: 16        16                 0.894  0.416667   0.305556
# PCA + SVM| subjc: 17        17                 0.919  0.555556   0.458618
# PCA + SVM| subjc: 18        18                 0.956  0.666667   0.614815
# PCA + SVM| subjc: 19        19                 0.928  0.472222   0.336111
# PCA + XGB| subjc: 10        10                 0.894  0.222222   0.266667
# PCA + XGB| subjc: 11        11                 0.908  0.472222   0.435185
# PCA + XGB| subjc: 12        12                 0.889  0.472222   0.361823
# PCA + XGB| subjc: 13        13                 0.922  0.472222   0.442857
# PCA + XGB| subjc: 14        14                 0.906  0.472222   0.406200
# PCA + XGB| subjc: 15        15                 0.903  0.472222   0.471024
# PCA + XGB| subjc: 16        16                 0.842  0.416667   0.371693
# PCA + XGB| subjc: 17        17                 0.894  0.500000   0.507846
# PCA + XGB| subjc: 18        18                 0.950  0.611111   0.622889
# PCA + XGB| subjc: 19        19                 0.892  0.416667   0.370370
# TmFq + Wvl + KNN| subjc: 10 10                 0.358  0.222222   0.280769
# TmFq + Wvl + KNN| subjc: 11 11                 0.314  0.111111   0.130291
# TmFq + Wvl + KNN| subjc: 12 12                 0.244  0.277778   0.268519
# TmFq + Wvl + KNN| subjc: 13 13                 0.344  0.361111   0.411706
# TmFq + Wvl + KNN| subjc: 14 14                 0.303  0.388889   0.291667
# TmFq + Wvl + KNN| subjc: 15 15                 0.406  0.388889   0.331746
# TmFq + Wvl + KNN| subjc: 16 16                 0.372  0.361111   0.373016
# TmFq + Wvl + KNN| subjc: 17 17                 0.369  0.388889   0.355159
# TmFq + Wvl + KNN| subjc: 18 18                 0.347  0.416667   0.351010
# TmFq + Wvl + KNN| subjc: 19 19                 0.339  0.250000   0.303953
# TmFq + Wvl + SVM| subjc: 10 10                 0.406  0.361111   0.250000
# TmFq + Wvl + SVM| subjc: 11 11                 0.439  0.444444   0.397444
# TmFq + Wvl + SVM| subjc: 12 12                 0.408  0.361111   0.258547
# TmFq + Wvl + SVM| subjc: 13 13                 0.486  0.388889   0.326720
# TmFq + Wvl + SVM| subjc: 14 14                 0.339  0.416667   0.353889
# TmFq + Wvl + SVM| subjc: 15 15                 0.503  0.388889   0.383504
# TmFq + Wvl + SVM| subjc: 16 16                 0.450  0.527778   0.454714
# TmFq + Wvl + SVM| subjc: 17 17                 0.458  0.416667   0.329444
# TmFq + Wvl + SVM| subjc: 18 18                 0.522  0.555556   0.419259
# TmFq + Wvl + SVM| subjc: 19 19                 0.453  0.333333   0.281746
# TmFq + Wvl + XGB| subjc: 10 10                 0.608  0.305556   0.256823
# TmFq + Wvl + XGB| subjc: 11 11                 0.558  0.333333   0.331790
# TmFq + Wvl + XGB| subjc: 12 12                 0.553  0.194444   0.194444
# TmFq + Wvl + XGB| subjc: 13 13                 0.608  0.444444   0.449074
# TmFq + Wvl + XGB| subjc: 14 14                 0.647  0.472222   0.474983
# TmFq + Wvl + XGB| subjc: 15 15                 0.669  0.416667   0.355219
# TmFq + Wvl + XGB| subjc: 16 16                 0.567  0.388889   0.371345
# TmFq + Wvl + XGB| subjc: 17 17                 0.631  0.333333   0.294904
# TmFq + Wvl + XGB| subjc: 18 18                 0.703  0.583333   0.551530
# TmFq + Wvl + XGB| subjc: 19 19                 0.611  0.333333   0.327778
#
#                                        Recall  F1_score       auc     kappa  \
# label                       subject
# PCA + KNN| subjc: 10        10       0.222222  0.214017  0.363281  0.028902
# PCA + KNN| subjc: 11        11       0.222222  0.189909  0.454839  0.076923
# PCA + KNN| subjc: 12        12       0.305556  0.327160  0.448387  0.110672
# PCA + KNN| subjc: 13        13       0.333333  0.360269  0.516129  0.136863
# PCA + KNN| subjc: 14        14       0.361111  0.375589  0.644531  0.145511
# PCA + KNN| subjc: 15        15       0.472222  0.485880  0.751613  0.280757
# PCA + KNN| subjc: 16        16       0.138889  0.128130  0.378906  0.003571
# PCA + KNN| subjc: 17        17       0.388889  0.417308  0.472656  0.206413
# PCA + KNN| subjc: 18        18       0.527778  0.554886  0.777419  0.362500
# PCA + KNN| subjc: 19        19       0.222222  0.238591  0.535484 -0.065539
# PCA + SVM| subjc: 10        10       0.194444  0.197838  0.437500 -0.139738
# PCA + SVM| subjc: 11        11       0.444444  0.356951  0.741935  0.045093
# PCA + SVM| subjc: 12        12       0.333333  0.344118  0.490323  0.060870
# PCA + SVM| subjc: 13        13       0.555556  0.475738  0.577419  0.236074
# PCA + SVM| subjc: 14        14       0.444444  0.379630  0.464844  0.108911
# PCA + SVM| subjc: 15        15       0.583333  0.537163  0.632258  0.356377
# PCA + SVM| subjc: 16        16       0.416667  0.341385  0.640625  0.000000
# PCA + SVM| subjc: 17        17       0.555556  0.484448  0.585938  0.267176
# PCA + SVM| subjc: 18        18       0.666667  0.636875  0.780645  0.499421
# PCA + SVM| subjc: 19        19       0.472222  0.373016  0.632258  0.061728
# PCA + XGB| subjc: 10        10       0.222222  0.242424  0.648438 -0.081545
# PCA + XGB| subjc: 11        11       0.472222  0.450244  0.596774  0.196240
# PCA + XGB| subjc: 12        12       0.472222  0.405483  0.338710  0.128662
# PCA + XGB| subjc: 13        13       0.472222  0.453984  0.567742  0.234899
# PCA + XGB| subjc: 14        14       0.472222  0.431741  0.566406  0.170909
# PCA + XGB| subjc: 15        15       0.472222  0.463492  0.774194  0.246696
# PCA + XGB| subjc: 16        16       0.416667  0.388258  0.703125  0.110588
# PCA + XGB| subjc: 17        17       0.500000  0.499510  0.527344  0.261117
# PCA + XGB| subjc: 18        18       0.611111  0.611722  0.790323  0.440622
# PCA + XGB| subjc: 19        19       0.416667  0.392049  0.587097  0.122970
# TmFq + Wvl + KNN| subjc: 10 10       0.222222  0.246018  0.742188 -0.052192
# TmFq + Wvl + KNN| subjc: 11 11       0.111111  0.119003  0.303226 -0.217759
# TmFq + Wvl + KNN| subjc: 12 12       0.277778  0.272727  0.483871 -0.049327
# TmFq + Wvl + KNN| subjc: 13 13       0.361111  0.345442  0.445161  0.024735
# TmFq + Wvl + KNN| subjc: 14 14       0.388889  0.333333  0.800781  0.025830
# TmFq + Wvl + KNN| subjc: 15 15       0.388889  0.356194  0.545161  0.083333
# TmFq + Wvl + KNN| subjc: 16 16       0.361111  0.355219  0.460938  0.127503
# TmFq + Wvl + KNN| subjc: 17 17       0.388889  0.369421  0.570312  0.066038
# TmFq + Wvl + KNN| subjc: 18 18       0.416667  0.380556  0.580645  0.095694
# TmFq + Wvl + KNN| subjc: 19 19       0.250000  0.268541  0.383871 -0.013556
# TmFq + Wvl + SVM| subjc: 10 10       0.361111  0.295455  0.738281 -0.061538
# TmFq + Wvl + SVM| subjc: 11 11       0.444444  0.413825  0.374194  0.125152
# TmFq + Wvl + SVM| subjc: 12 12       0.361111  0.300505  0.483871 -0.056122
# TmFq + Wvl + SVM| subjc: 13 13       0.388889  0.353042  0.461290  0.051497
# TmFq + Wvl + SVM| subjc: 14 14       0.416667  0.368135  0.562500  0.051443
# TmFq + Wvl + SVM| subjc: 15 15       0.388889  0.379872  0.548387  0.119021
# TmFq + Wvl + SVM| subjc: 16 16       0.527778  0.486376  0.597656  0.269690
# TmFq + Wvl + SVM| subjc: 17 17       0.416667  0.364054  0.480469  0.050251
# TmFq + Wvl + SVM| subjc: 18 18       0.555556  0.475042  0.825806  0.279099
# TmFq + Wvl + SVM| subjc: 19 19       0.333333  0.305199  0.367742 -0.018868
# TmFq + Wvl + XGB| subjc: 10 10       0.305556  0.275740  0.375000 -0.029748
# TmFq + Wvl + XGB| subjc: 11 11       0.333333  0.319934  0.567742  0.006897
# TmFq + Wvl + XGB| subjc: 12 12       0.194444  0.194444  0.703226 -0.167785
# TmFq + Wvl + XGB| subjc: 13 13       0.444444  0.445887  0.577419  0.190101
# TmFq + Wvl + XGB| subjc: 14 14       0.472222  0.428164  0.699219  0.170909
# TmFq + Wvl + XGB| subjc: 15 15       0.416667  0.381746  0.429032  0.094611
# TmFq + Wvl + XGB| subjc: 16 16       0.388889  0.379880  0.640625  0.098976
# TmFq + Wvl + XGB| subjc: 17 17       0.333333  0.310674  0.515625  0.021518
# TmFq + Wvl + XGB| subjc: 18 18       0.583333  0.551179  0.467742  0.344660
# TmFq + Wvl + XGB| subjc: 19 19       0.333333  0.330247  0.319355  0.027027
#
#                                      mathew_coef
# label                       subject
# PCA + KNN| subjc: 10        10          0.031456
# PCA + KNN| subjc: 11        11          0.089040
# PCA + KNN| subjc: 12        12          0.118131
# PCA + KNN| subjc: 13        13          0.143648
# PCA + KNN| subjc: 14        14          0.151441
# PCA + KNN| subjc: 15        15          0.295389
# PCA + KNN| subjc: 16        16          0.004270
# PCA + KNN| subjc: 17        17          0.215785
# PCA + KNN| subjc: 18        18          0.371489
# PCA + KNN| subjc: 19        19         -0.067857
# PCA + SVM| subjc: 10        10         -0.141456
# PCA + SVM| subjc: 11        11          0.051486
# PCA + SVM| subjc: 12        12          0.061421
# PCA + SVM| subjc: 13        13          0.269542
# PCA + SVM| subjc: 14        14          0.114646
# PCA + SVM| subjc: 15        15          0.366950
# PCA + SVM| subjc: 16        16          0.000000
# PCA + SVM| subjc: 17        17          0.291785
# PCA + SVM| subjc: 18        18          0.505133
# PCA + SVM| subjc: 19        19          0.077177
# PCA + XGB| subjc: 10        10         -0.082566
# PCA + XGB| subjc: 11        11          0.198911
# PCA + XGB| subjc: 12        12          0.139855
# PCA + XGB| subjc: 13        13          0.238378
# PCA + XGB| subjc: 14        14          0.175896
# PCA + XGB| subjc: 15        15          0.253400
# PCA + XGB| subjc: 16        16          0.113403
# PCA + XGB| subjc: 17        17          0.262364
# PCA + XGB| subjc: 18        18          0.443582
# PCA + XGB| subjc: 19        19          0.124232
# TmFq + Wvl + KNN| subjc: 10 10         -0.053213
# TmFq + Wvl + KNN| subjc: 11 11         -0.223095
# TmFq + Wvl + KNN| subjc: 12 12         -0.049889
# TmFq + Wvl + KNN| subjc: 13 13          0.025467
# TmFq + Wvl + KNN| subjc: 14 14          0.027195
# TmFq + Wvl + KNN| subjc: 15 15          0.085542
# TmFq + Wvl + KNN| subjc: 16 16          0.131041
# TmFq + Wvl + KNN| subjc: 17 17          0.066785
# TmFq + Wvl + KNN| subjc: 18 18          0.097272
# TmFq + Wvl + KNN| subjc: 19 19         -0.013920
# TmFq + Wvl + SVM| subjc: 10 10         -0.066579
# TmFq + Wvl + SVM| subjc: 11 11          0.128491
# TmFq + Wvl + SVM| subjc: 12 12         -0.060720
# TmFq + Wvl + SVM| subjc: 13 13          0.052772
# TmFq + Wvl + SVM| subjc: 14 14          0.054668
# TmFq + Wvl + SVM| subjc: 15 15          0.122304
# TmFq + Wvl + SVM| subjc: 16 16          0.276251
# TmFq + Wvl + SVM| subjc: 17 17          0.053589
# TmFq + Wvl + SVM| subjc: 18 18          0.297339
# TmFq + Wvl + SVM| subjc: 19 19         -0.019154
# TmFq + Wvl + XGB| subjc: 10 10         -0.030287
# TmFq + Wvl + XGB| subjc: 11 11          0.007174
# TmFq + Wvl + XGB| subjc: 12 12         -0.169302
# TmFq + Wvl + XGB| subjc: 13 13          0.190316
# TmFq + Wvl + XGB| subjc: 14 14          0.178639
# TmFq + Wvl + XGB| subjc: 15 15          0.096953
# TmFq + Wvl + XGB| subjc: 16 16          0.099792
# TmFq + Wvl + XGB| subjc: 17 17          0.022133
# TmFq + Wvl + XGB| subjc: 18 18          0.354287
# TmFq + Wvl + XGB| subjc: 19 19          0.027337

# %%
top_1 = df_ml.iloc[:,1]
top_3 = df_ml.iloc[:,4]
top_5 = df_ml.iloc[:,0]
xlabels = df_ml.iloc[:,-1]
N = len(df_ml.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars
fig, ax = plt.subplots(figsize=(24,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
rects2 = ax.bar(ind + width, top_3, width, color='#f5c767')
rects3 = ax.bar(ind + 2*width, top_5, width, color='#7a61ba')
ax.set_xticks(ind + width)
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)
ax.set_title('Metrics for ML models | Inter-subject')
ax.legend((rects1[0], rects2[0],rects3[0]),('Acc Test', 'F1 Score Test','Acc Cross Validation'),bbox_to_anchor=(1.13, 1.01))
ax.set_ylim([0, 1])
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)
labelvalue(rects2)
labelvalue(rects3)
plt.savefig('../artifacts/barplot_ml.png',dpi=200, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Transformers Models

# %%
df_trans["label"] = df_trans.model  + "| subjc: " + df_trans.subject.astype(str)  
trans_gb = df_trans.groupby(['model','subject']).mean()

# %%
df_trans.head()
# Out:
#    acc_test  Precision    Recall  F1_score       auc     kappa  mathew_coef  \
# 0  0.611111   0.495370  0.611111  0.539683  0.890625  0.376238     0.395898
# 1  0.500000   0.321429  0.500000  0.391304  0.671875  0.133690     0.154462
# 2  0.444444   0.327778  0.444444  0.360234  0.812500  0.174312     0.201626
# 3  0.388889   0.300505  0.388889  0.337037  0.515625  0.057143     0.059374
# 4  0.388889   0.372685  0.388889  0.369514  0.625000  0.131579     0.139609
#
#             model_name                model          dataset  subject  \
# 0  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       18
# 1          Transformer          Transformer  Motor Imaginary       19
# 2  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       15
# 3  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       12
# 4          Transformer          Transformer  Motor Imaginary       16
#
#    acc_train   acc_val                           label
# 0   0.944444  0.611111  Transformer Pos Enc| subjc: 18
# 1   0.241667  0.277778          Transformer| subjc: 19
# 2   0.255556  0.277778  Transformer Pos Enc| subjc: 15
# 3   0.380556  0.444444  Transformer Pos Enc| subjc: 12
# 4   0.230556  0.166667          Transformer| subjc: 16

# %%
top_1 = df_trans.iloc[:,-3]
top_3 = df_trans.iloc[:,-2]
top_5 = df_trans.iloc[:,0]
xlabels = df_trans.iloc[:,-1]
N = len(df_trans.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars
fig, ax = plt.subplots(figsize=(24,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
rects2 = ax.bar(ind + width, top_3, width, color='#f5c767')
rects3 = ax.bar(ind + 2*width, top_5, width, color='#7a61ba')
ax.set_xticks(ind + width)
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)

ax.set_title('Metrics for Transformer based models | Intra-subject')
ax.legend((rects1[0], rects2[0],rects3[0]),('Acc Train', 'Acc Validation','Acc Test'),bbox_to_anchor=(1.13, 1.01))
ax.set_ylim([0, 1])
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)
labelvalue(rects2)
labelvalue(rects3)
plt.savefig('../artifacts/barplot_trans.png',dpi=200, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Comparing Models

# %%
all_models = pd.concat([
                    df_trans[['model','acc_test']].rename(columns = {'model':'Model', 'acc_test':'Accuracy'}), 
                    df_cnn[['label','acc_test']].rename(columns = {'label':'Model', 'acc_test':'Accuracy'}), 
                    df_ml[['label','Accuracy']].rename(columns = {'label':'Model'})], axis=0, ignore_index=True)
all_models = all_models.sort_values(['Accuracy'], ascending=False)
all_models.to_csv('../artifacts/results_all_models.csv', index=False, header=True)                    
all_models
# Out:
#                            Model  Accuracy
# 20             EEGNet| subjc: 18  0.833333
# 22        DeepConvNet| subjc: 18  0.777778
# 21        HopefullNet| subjc: 18  0.777778
# 61          PCA + SVM| subjc: 18  0.666667
# 24             EEGNet| subjc: 15  0.666667
# ..                           ...       ...
# 17                   Transformer  0.111111
# 16           Transformer Pos Enc  0.111111
# 117  TmFq + Wvl + KNN| subjc: 11  0.111111
# 18                   Transformer  0.055556
# 19                   Transformer  0.055556
#
# [120 rows x 2 columns]

# %%
top_1 = all_models.iloc[:,1]
xlabels = all_models.iloc[:,0]
N = len(all_models.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.7      # the width of the bars
fig, ax = plt.subplots(figsize=(30,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
ax.set_xticks(ind )
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)
ax.set_title('Metrics for All models | Intra-subject')
# ax.legend(rects1[0],'Accuracy Test')
ax.set_ylim([0, 1])

def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)

plt.savefig('../artifacts/barplot_all.png',dpi=200, format='png', bbox_inches='tight')
plt.show()
