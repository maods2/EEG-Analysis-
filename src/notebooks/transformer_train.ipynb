# %%
import numpy as np
from sklearn.model_selection import train_test_split
from utils.plots import plot_acc_loss_keras
from utils.dataloader import load_eeg_data_edf, load_eeg_data_gdf, load_eeg_data_mat
from utils.dataloader import load_eeg_data_mat
from models.transformers import Transformer
import keras
from tensorflow.keras import utils as np_utils
import tensorflow as tf

# %%
physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
directory = 'C:/Users/Maods/Documents/Repos/EEG-Analysis-/data/eeg-motor-movementimagery-dataset-1.0.0/files/'
extension = '**/*.edf'
x_movementimagery, y_movementimagery  = load_eeg_data_edf(directory, extension)
nb_classes = np.unique(y_movementimagery).shape[0]
_, channels, samples = np.shape(x_movementimagery)
# Out:
# Extracting EDF parameters from C:\Users\Maods\Documents\Repos\EEG-Analysis-\data\eeg-motor-movementimagery-dataset-1.0.0\files\S001\S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Not setting metadata
# 15 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 15 events and 113 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\Users\Maods\Documents\Repos\EEG-Analysis-\data\eeg-motor-movementimagery-dataset-1.0.0\files\S001\S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# ...

# %%
x_movementimagery.shape
# Out:
# (6915, 64, 113)

# %%
elements, channels, samples = x_movementimagery.shape

x_movementimagery = x_movementimagery.reshape(elements, samples, channels)

X_train, X_test, Y_train, Y_test = train_test_split( x_movementimagery, y_movementimagery , test_size=0.5, random_state=42)

# %%
input_shape = X_train.shape[1:]
n_classes = len(np.unique(Y_train))

model = Transformer(input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=64,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
    n_classes=n_classes
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
# model.summary()

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    X_train,
    Y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,

)

model.evaluate(X_test, Y_test, verbose=1)
# Out:
# Epoch 1/200
# 44/44 [==============================] - 2s 49ms/step - loss: 1.3919 - sparse_categorical_accuracy: 0.2550 - val_loss: 1.3894 - val_sparse_categorical_accuracy: 0.2486
# Epoch 2/200
# 44/44 [==============================] - 2s 46ms/step - loss: 1.3944 - sparse_categorical_accuracy: 0.2535 - val_loss: 1.3952 - val_sparse_categorical_accuracy: 0.2514
# Epoch 3/200
# 44/44 [==============================] - 2s 46ms/step - loss: 1.3963 - sparse_categorical_accuracy: 0.2423 - val_loss: 1.3868 - val_sparse_categorical_accuracy: 0.2399
# Epoch 4/200
# 44/44 [==============================] - 2s 46ms/step - loss: 1.3898 - sparse_categorical_accuracy: 0.2499 - val_loss: 1.3877 - val_sparse_categorical_accuracy: 0.2514
# Epoch 5/200
# 44/44 [==============================] - 2s 46ms/step - loss: 1.3926 - sparse_categorical_accuracy: 0.2448 - val_loss: 1.3876 - val_sparse_categorical_accuracy: 0.2514
# Epoch 6/200
# ...
