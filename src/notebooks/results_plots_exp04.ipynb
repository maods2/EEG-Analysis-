# %%
import pandas as pd
import matplotlib.pyplot as plt
import sns
import numpy as np

# %%
df_ml = pd.read_csv('../artifacts/experiment_04/results_ml_models.csv')
df_cnn = pd.read_csv('../artifacts/experiment_04/results_cnn_models.csv')
df_trans = pd.read_csv('../artifacts/experiment_04/results_Transformer_models.csv')

# %% [markdown]
# # CNN Models

# %%
df_cnn["label"] = df_cnn.model  + "| subjc: " + df_cnn.subject.astype(str)  
df_cnn.groupby(['model','subject']).mean()
# Out:
#                         acc_test  Precision    Recall  F1_score       auc  \
# model          subject
# DeepConvNet    10       0.222222   0.327778  0.222222  0.251323  0.687500
#                11       0.166667   0.541667  0.166667  0.229437  0.593750
#                12       0.333333   0.472222  0.333333  0.388889  0.250000
#                13       0.500000   0.461111  0.500000  0.479532  0.250000
#                14       0.333333   0.272222  0.333333  0.294904  0.484375
#                15       0.666667   0.712963  0.666667  0.681699  0.750000
#                16       0.222222   0.387346  0.222222  0.250971  0.296875
#                17       0.555556   0.527778  0.555556  0.539683  0.781250
#                18       0.833333   0.884259  0.833333  0.832209  0.671875
#                19       0.444444   0.453704  0.444444  0.444444  0.406250
# EEGNet         10       0.277778   0.441667  0.277778  0.314103  0.781250
#                11       0.277778   0.366667  0.277778  0.293860  0.484375
#                12       0.500000   0.574074  0.500000  0.509259  0.375000
#                13       0.500000   0.344729  0.500000  0.408081  0.343750
#                14       0.444444   0.388889  0.444444  0.407407  0.625000
#                15       0.722222   0.709259  0.722222  0.707018  0.609375
#                16       0.333333   0.379365  0.333333  0.344246  0.375000
#                17       0.611111   0.464646  0.611111  0.524074  0.546875
#                18       0.777778   0.754630  0.777778  0.757890  0.828125
#                19       0.388889   0.397222  0.388889  0.384687  0.390625
# HopefullNet    10       0.111111   0.012346  0.111111  0.022222  0.500000
#                11       0.500000   0.281250  0.500000  0.360000  0.437500
#                12       0.388889   0.291667  0.388889  0.333333  0.312500
#                13       0.055556   0.009259  0.055556  0.015873  0.687500
#                14       0.500000   0.264706  0.500000  0.346154  0.468750
#                15       0.722222   0.718519  0.722222  0.682943  0.859375
#                16       0.111111   0.012346  0.111111  0.022222  0.500000
#                17       0.111111   0.012346  0.111111  0.022222  0.500000
#                18       0.722222   0.814815  0.722222  0.731699  0.718750
#                19       0.388889   0.433862  0.388889  0.398148  0.312500
# ShallowConvNet 10       0.277778   0.277778  0.277778  0.277778  0.218750
#                11       0.611111   0.466667  0.611111  0.508333  0.406250
#                12       0.555556   0.355556  0.555556  0.430556  0.671875
#                13       0.500000   0.344729  0.500000  0.408081  0.656250
#                14       0.500000   0.363248  0.500000  0.419192  0.578125
#                15       0.611111   0.637037  0.611111  0.609162  0.734375
#                16       0.388889   0.350000  0.388889  0.368421  0.625000
#                17       0.611111   0.449074  0.611111  0.517460  0.937500
#                18       0.666667   0.722222  0.666667  0.677778  0.687500
#                19       0.444444   0.361111  0.444444  0.389418  0.312500
#
#                            kappa  mathew_coef  acc_train   acc_val
# model          subject
# DeepConvNet    10      -0.012048    -0.012634   0.919444  0.222222
#                11       0.000000     0.000000   0.933333  0.222222
#                12       0.114754     0.121304   0.955556  0.277778
#                13       0.253456     0.257189   0.983333  0.444444
#                14       0.009174     0.009637   0.991667  0.333333
#                15       0.530435     0.535273   0.986111  0.333333
#                16       0.023256     0.027274   0.952778  0.333333
#                17       0.348416     0.350014   0.961111  0.333333
#                18       0.770213     0.784145   0.994444  0.500000
#                19       0.192825     0.193694   0.977778  0.555556
# EEGNet         10       0.082353     0.089140   0.736111  0.222222
#                11      -0.078341    -0.081498   0.791667  0.388889
#                12       0.276786     0.291340   0.794444  0.444444
#                13       0.177665     0.197128   0.861111  0.500000
#                14       0.192825     0.197281   0.811111  0.444444
#                15       0.583333     0.589197   0.880556  0.666667
#                16       0.080851     0.083721   0.780556  0.500000
#                17       0.385366     0.411525   0.841667  0.444444
#                18       0.684211     0.690374   0.905556  0.611111
#                19       0.139130     0.142863   0.816667  0.722222
# HopefullNet    10       0.000000     0.000000   0.316667  0.222222
#                11       0.079545     0.117452   0.333333  0.222222
#                12       0.024631     0.027042   0.241667  0.166667
#                13      -0.081272    -0.124392   0.330556  0.111111
#                14       0.041420     0.080572   0.369444  0.111111
#                15       0.585253     0.605752   0.872222  0.555556
#                16       0.000000     0.000000   0.294444  0.111111
#                17       0.000000     0.000000   0.305556  0.166667
#                18       0.610390     0.621296   0.813889  0.444444
#                19       0.164557     0.168260   0.830556  0.555556
# ShallowConvNet 10      -0.049327    -0.050002   0.977778  0.277778
#                11       0.303867     0.380735   0.980556  0.444444
#                12       0.213115     0.269975   1.000000  0.500000
#                13       0.173469     0.190161   0.997222  0.388889
#                14       0.169231     0.183299   0.997222  0.500000
#                15       0.416667     0.420855   1.000000  0.444444
#                16       0.083333     0.084171   0.983333  0.388889
#                17       0.376238     0.395898   0.988889  0.500000
#                18       0.515695     0.522749   1.000000  0.611111
#                19       0.108911     0.116731   0.997222  0.500000

# %%
df_cnn.head()
# Out:
#    acc_test  Precision    Recall  F1_score       auc     kappa  mathew_coef  \
# 0  0.833333   0.884259  0.833333  0.832209  0.671875  0.770213     0.784145
# 1  0.777778   0.754630  0.777778  0.757890  0.828125  0.684211     0.690374
# 2  0.722222   0.709259  0.722222  0.707018  0.609375  0.583333     0.589197
# 3  0.722222   0.718519  0.722222  0.682943  0.859375  0.585253     0.605752
# 4  0.722222   0.814815  0.722222  0.731699  0.718750  0.610390     0.621296
#
#     model_name        model          dataset  subject  acc_train   acc_val  \
# 0  DeepConvNet  DeepConvNet  Motor Imaginary       18   0.994444  0.500000
# 1       EEGNet       EEGNet  Motor Imaginary       18   0.905556  0.611111
# 2       EEGNet       EEGNet  Motor Imaginary       15   0.880556  0.666667
# 3  HopefullNet  HopefullNet  Motor Imaginary       15   0.872222  0.555556
# 4  HopefullNet  HopefullNet  Motor Imaginary       18   0.813889  0.444444
#
#                     label
# 0  DeepConvNet| subjc: 18
# 1       EEGNet| subjc: 18
# 2       EEGNet| subjc: 15
# 3  HopefullNet| subjc: 15
# 4  HopefullNet| subjc: 18

# %%
top_1 = df_cnn.iloc[:,-3]
top_3 = df_cnn.iloc[:,-2]
top_5 = df_cnn.iloc[:,0]
xlabels = df_cnn.iloc[:,-1]
N = len(df_cnn.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars
fig, ax = plt.subplots(figsize=(24,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
rects2 = ax.bar(ind + width, top_3, width, color='#f5c767')
rects3 = ax.bar(ind + 2*width, top_5, width, color='#7a61ba')
ax.set_xticks(ind + width)
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)
ax.set_title('Accuracy for CNNs models | Intra-subject')
ax.legend((rects1[0], rects2[0],rects3[0]),('Acc Train', 'Acc Validation','Acc Test'),bbox_to_anchor=(1.13, 1.01))
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)
labelvalue(rects2)
labelvalue(rects3)
plt.savefig('../artifacts/barplot_cnn.png',dpi=200, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Machine Learning Models

# %%
df_ml['label'] = df_ml.pipeline.replace("time domain features -> wavelet", "TmFq + Wvl") +' + '+ df_ml.model_name
df_ml["label"] = df_ml.label  + "| subjc: " + df_ml.subject.astype(str)  
df_ml.groupby(['label','subject']).mean()
# Out:
#                                      cross_val_score  Accuracy  Precision  \
# label                       subject
# PCA + KNN| subjc: 10        10                 0.842  0.561728   0.672006
# PCA + KNN| subjc: 11        11                 0.951  0.910494   0.916381
# PCA + KNN| subjc: 12        12                 0.991  1.000000   1.000000
# PCA + KNN| subjc: 13        13                 0.991  0.981481   0.981685
# PCA + KNN| subjc: 14        14                 0.995  0.993827   0.994136
# PCA + KNN| subjc: 15        15                 0.999  0.993827   0.994121
# PCA + KNN| subjc: 16        16                 0.987  0.972222   0.974240
# PCA + KNN| subjc: 17        17                 0.973  0.941358   0.944712
# PCA + KNN| subjc: 18        18                 0.989  0.990741   0.991110
# PCA + KNN| subjc: 19        19                 0.997  0.993827   0.993902
# PCA + SVM| subjc: 10        10                 0.900  0.750000   0.763808
# PCA + SVM| subjc: 11        11                 0.941  0.805556   0.812330
# PCA + SVM| subjc: 12        12                 0.975  0.947531   0.949383
# PCA + SVM| subjc: 13        13                 0.984  0.947531   0.950394
# PCA + SVM| subjc: 14        14                 0.959  0.895062   0.897378
# PCA + SVM| subjc: 15        15                 0.997  0.987654   0.987960
# PCA + SVM| subjc: 16        16                 0.982  0.935185   0.940364
# PCA + SVM| subjc: 17        17                 0.974  0.922840   0.923036
# PCA + SVM| subjc: 18        18                 0.999  0.984568   0.984518
# PCA + SVM| subjc: 19        19                 0.984  0.966049   0.966634
# PCA + XGB| subjc: 10        10                 0.984  0.929012   0.929878
# PCA + XGB| subjc: 11        11                 0.990  0.929012   0.932219
# PCA + XGB| subjc: 12        12                 0.999  0.993827   0.993902
# PCA + XGB| subjc: 13        13                 0.998  0.981481   0.982143
# PCA + XGB| subjc: 14        14                 0.998  0.972222   0.972730
# PCA + XGB| subjc: 15        15                 0.999  0.996914   0.996989
# PCA + XGB| subjc: 16        16                 0.998  1.000000   1.000000
# PCA + XGB| subjc: 17        17                 0.997  0.990741   0.990909
# PCA + XGB| subjc: 18        18                 0.998  0.984568   0.984939
# PCA + XGB| subjc: 19        19                 0.999  0.990741   0.990909
# TmFq + Wvl + KNN| subjc: 10 10                 0.357  0.246914   0.329541
# TmFq + Wvl + KNN| subjc: 11 11                 0.377  0.246914   0.345466
# TmFq + Wvl + KNN| subjc: 12 12                 0.481  0.376543   0.467801
# TmFq + Wvl + KNN| subjc: 13 13                 0.356  0.274691   0.378760
# TmFq + Wvl + KNN| subjc: 14 14                 0.361  0.283951   0.384970
# TmFq + Wvl + KNN| subjc: 15 15                 0.459  0.358025   0.442073
# TmFq + Wvl + KNN| subjc: 16 16                 0.422  0.240741   0.321758
# TmFq + Wvl + KNN| subjc: 17 17                 0.358  0.265432   0.367490
# TmFq + Wvl + KNN| subjc: 18 18                 0.497  0.478395   0.542996
# TmFq + Wvl + KNN| subjc: 19 19                 0.380  0.367284   0.496407
# TmFq + Wvl + SVM| subjc: 10 10                 0.362  0.435185   0.361192
# TmFq + Wvl + SVM| subjc: 11 11                 0.364  0.469136   0.458051
# TmFq + Wvl + SVM| subjc: 12 12                 0.390  0.432099   0.460651
# TmFq + Wvl + SVM| subjc: 13 13                 0.388  0.364198   0.426626
# TmFq + Wvl + SVM| subjc: 14 14                 0.354  0.320988   0.352425
# TmFq + Wvl + SVM| subjc: 15 15                 0.475  0.416667   0.462952
# TmFq + Wvl + SVM| subjc: 16 16                 0.366  0.333333   0.363589
# TmFq + Wvl + SVM| subjc: 17 17                 0.376  0.401235   0.424701
# TmFq + Wvl + SVM| subjc: 18 18                 0.501  0.574074   0.593210
# TmFq + Wvl + SVM| subjc: 19 19                 0.393  0.388889   0.417103
# TmFq + Wvl + XGB| subjc: 10 10                 0.567  0.358025   0.340293
# TmFq + Wvl + XGB| subjc: 11 11                 0.650  0.416667   0.404201
# TmFq + Wvl + XGB| subjc: 12 12                 0.827  0.608025   0.616914
# TmFq + Wvl + XGB| subjc: 13 13                 0.718  0.481481   0.508980
# TmFq + Wvl + XGB| subjc: 14 14                 0.652  0.395062   0.408708
# TmFq + Wvl + XGB| subjc: 15 15                 0.781  0.549383   0.578212
# TmFq + Wvl + XGB| subjc: 16 16                 0.707  0.435185   0.468280
# TmFq + Wvl + XGB| subjc: 17 17                 0.650  0.416667   0.435243
# TmFq + Wvl + XGB| subjc: 18 18                 0.791  0.666667   0.680037
# TmFq + Wvl + XGB| subjc: 19 19                 0.764  0.487654   0.509580
#
#                                        Recall  F1_score       auc     kappa  \
# label                       subject
# PCA + KNN| subjc: 10        10       0.561728  0.564332  0.396611  0.441420
# PCA + KNN| subjc: 11        11       0.910494  0.911126  0.520857  0.873221
# PCA + KNN| subjc: 12        12       1.000000  1.000000  0.572438  1.000000
# PCA + KNN| subjc: 13        13       0.981481  0.981482  0.567181  0.973018
# PCA + KNN| subjc: 14        14       0.993827  0.993887  0.562937  0.991050
# PCA + KNN| subjc: 15        15       0.993827  0.993883  0.565371  0.991051
# PCA + KNN| subjc: 16        16       0.972222  0.972466  0.550699  0.960067
# PCA + KNN| subjc: 17        17       0.941358  0.941514  0.534091  0.916368
# PCA + KNN| subjc: 18        18       0.990741  0.990792  0.561837  0.986600
# PCA + KNN| subjc: 19        19       0.993827  0.993767  0.579505  0.990991
# PCA + SVM| subjc: 10        10       0.750000  0.754054  0.505502  0.647656
# PCA + SVM| subjc: 11        11       0.805556  0.807154  0.481643  0.723669
# PCA + SVM| subjc: 12        12       0.947531  0.947692  0.558304  0.924283
# PCA + SVM| subjc: 13        13       0.947531  0.948258  0.541153  0.923804
# PCA + SVM| subjc: 14        14       0.895062  0.895533  0.531331  0.849360
# PCA + SVM| subjc: 15        15       0.987654  0.987552  0.579505  0.982011
# PCA + SVM| subjc: 16        16       0.935185  0.935787  0.512054  0.907719
# PCA + SVM| subjc: 17        17       0.922840  0.922498  0.538830  0.887762
# PCA + SVM| subjc: 18        18       0.984568  0.984447  0.579505  0.977477
# PCA + SVM| subjc: 19        19       0.966049  0.966171  0.553176  0.950699
# PCA + XGB| subjc: 10        10       0.929012  0.928591  0.565977  0.895306
# PCA + XGB| subjc: 11        11       0.929012  0.928741  0.576489  0.894431
# PCA + XGB| subjc: 12        12       0.993827  0.993808  0.568948  0.990989
# PCA + XGB| subjc: 13        13       0.981481  0.981287  0.582910  0.972788
# PCA + XGB| subjc: 14        14       0.972222  0.972024  0.549181  0.959307
# PCA + XGB| subjc: 15        15       0.996914  0.996914  0.581143  0.995511
# PCA + XGB| subjc: 16        16       1.000000  1.000000  0.566434  1.000000
# PCA + XGB| subjc: 17        17       0.990741  0.990689  0.565881  0.986462
# PCA + XGB| subjc: 18        18       0.984568  0.984402  0.588339  0.977400
# PCA + XGB| subjc: 19        19       0.990741  0.990725  0.583039  0.986463
# TmFq + Wvl + KNN| subjc: 10 10       0.246914  0.264614  0.462060  0.028951
# TmFq + Wvl + KNN| subjc: 11 11       0.246914  0.267235  0.487331  0.040221
# TmFq + Wvl + KNN| subjc: 12 12       0.376543  0.397720  0.514781  0.187849
# TmFq + Wvl + KNN| subjc: 13 13       0.274691  0.297999  0.538051  0.070114
# TmFq + Wvl + KNN| subjc: 14 14       0.283951  0.311731  0.583640  0.066340
# TmFq + Wvl + KNN| subjc: 15 15       0.358025  0.381656  0.563734  0.151704
# TmFq + Wvl + KNN| subjc: 16 16       0.240741  0.253908  0.448657  0.032249
# TmFq + Wvl + KNN| subjc: 17 17       0.265432  0.287221  0.446172  0.058875
# TmFq + Wvl + KNN| subjc: 18 18       0.478395  0.501931  0.631949  0.287022
# TmFq + Wvl + KNN| subjc: 19 19       0.367284  0.402568  0.551969  0.178946
# TmFq + Wvl + SVM| subjc: 10 10       0.435185  0.371135  0.510475  0.033025
# TmFq + Wvl + SVM| subjc: 11 11       0.469136  0.460249  0.599845  0.211723
# TmFq + Wvl + SVM| subjc: 12 12       0.432099  0.438641  0.607817  0.194389
# TmFq + Wvl + SVM| subjc: 13 13       0.364198  0.387134  0.611652  0.131921
# TmFq + Wvl + SVM| subjc: 14 14       0.320988  0.329961  0.542602  0.053876
# TmFq + Wvl + SVM| subjc: 15 15       0.416667  0.431715  0.547143  0.194539
# TmFq + Wvl + SVM| subjc: 16 16       0.333333  0.341731  0.495997  0.086263
# TmFq + Wvl + SVM| subjc: 17 17       0.401235  0.409619  0.543752  0.153671
# TmFq + Wvl + SVM| subjc: 18 18       0.574074  0.577980  0.572438  0.394860
# TmFq + Wvl + SVM| subjc: 19 19       0.388889  0.394578  0.565112  0.150676
# TmFq + Wvl + XGB| subjc: 10 10       0.358025  0.347761  0.490009  0.039795
# TmFq + Wvl + XGB| subjc: 11 11       0.416667  0.409199  0.553176  0.130997
# TmFq + Wvl + XGB| subjc: 12 12       0.608025  0.610914  0.534301  0.433676
# TmFq + Wvl + XGB| subjc: 13 13       0.481481  0.492212  0.588684  0.273911
# TmFq + Wvl + XGB| subjc: 14 14       0.395062  0.400498  0.576049  0.139302
# TmFq + Wvl + XGB| subjc: 15 15       0.549383  0.559953  0.571619  0.369918
# TmFq + Wvl + XGB| subjc: 16 16       0.435185  0.447619  0.553368  0.216191
# TmFq + Wvl + XGB| subjc: 17 17       0.416667  0.423875  0.556404  0.175384
# TmFq + Wvl + XGB| subjc: 18 18       0.666667  0.671877  0.633759  0.523166
# TmFq + Wvl + XGB| subjc: 19 19       0.487654  0.496539  0.586443  0.274288
#
#                                      mathew_coef
# label                       subject
# PCA + KNN| subjc: 10        10          0.467759
# PCA + KNN| subjc: 11        11          0.875399
# PCA + KNN| subjc: 12        12          1.000000
# PCA + KNN| subjc: 13        13          0.973060
# PCA + KNN| subjc: 14        14          0.991111
# PCA + KNN| subjc: 15        15          0.991112
# PCA + KNN| subjc: 16        16          0.960655
# PCA + KNN| subjc: 17        17          0.917745
# PCA + KNN| subjc: 18        18          0.986707
# PCA + KNN| subjc: 19        19          0.991052
# PCA + SVM| subjc: 10        10          0.650015
# PCA + SVM| subjc: 11        11          0.725176
# PCA + SVM| subjc: 12        12          0.924717
# PCA + SVM| subjc: 13        13          0.924099
# PCA + SVM| subjc: 14        14          0.849963
# PCA + SVM| subjc: 15        15          0.982109
# PCA + SVM| subjc: 16        16          0.909424
# PCA + SVM| subjc: 17        17          0.887922
# PCA + SVM| subjc: 18        18          0.977537
# PCA + SVM| subjc: 19        19          0.950766
# PCA + XGB| subjc: 10        10          0.895991
# PCA + XGB| subjc: 11        11          0.896137
# PCA + XGB| subjc: 12        12          0.991037
# PCA + XGB| subjc: 13        13          0.973211
# PCA + XGB| subjc: 14        14          0.959560
# PCA + XGB| subjc: 15        15          0.995524
# PCA + XGB| subjc: 16        16          1.000000
# PCA + XGB| subjc: 17        17          0.986571
# PCA + XGB| subjc: 18        18          0.977629
# PCA + XGB| subjc: 19        19          0.986559
# TmFq + Wvl + KNN| subjc: 10 10          0.030587
# TmFq + Wvl + KNN| subjc: 11 11          0.042650
# TmFq + Wvl + KNN| subjc: 12 12          0.196048
# TmFq + Wvl + KNN| subjc: 13 13          0.074234
# TmFq + Wvl + KNN| subjc: 14 14          0.069481
# TmFq + Wvl + KNN| subjc: 15 15          0.156736
# TmFq + Wvl + KNN| subjc: 16 16          0.034210
# TmFq + Wvl + KNN| subjc: 17 17          0.062289
# TmFq + Wvl + KNN| subjc: 18 18          0.291139
# TmFq + Wvl + KNN| subjc: 19 19          0.187536
# TmFq + Wvl + SVM| subjc: 10 10          0.037486
# TmFq + Wvl + SVM| subjc: 11 11          0.212594
# TmFq + Wvl + SVM| subjc: 12 12          0.196788
# TmFq + Wvl + SVM| subjc: 13 13          0.134220
# TmFq + Wvl + SVM| subjc: 14 14          0.054971
# TmFq + Wvl + SVM| subjc: 15 15          0.197666
# TmFq + Wvl + SVM| subjc: 16 16          0.087520
# TmFq + Wvl + SVM| subjc: 17 17          0.154674
# TmFq + Wvl + SVM| subjc: 18 18          0.397877
# TmFq + Wvl + SVM| subjc: 19 19          0.153727
# TmFq + Wvl + XGB| subjc: 10 10          0.039947
# TmFq + Wvl + XGB| subjc: 11 11          0.131344
# TmFq + Wvl + XGB| subjc: 12 12          0.434250
# TmFq + Wvl + XGB| subjc: 13 13          0.275383
# TmFq + Wvl + XGB| subjc: 14 14          0.139711
# TmFq + Wvl + XGB| subjc: 15 15          0.372182
# TmFq + Wvl + XGB| subjc: 16 16          0.218028
# TmFq + Wvl + XGB| subjc: 17 17          0.176108
# TmFq + Wvl + XGB| subjc: 18 18          0.524053
# TmFq + Wvl + XGB| subjc: 19 19          0.275277

# %%
top_1 = df_ml.iloc[:,1]
top_3 = df_ml.iloc[:,4]
top_5 = df_ml.iloc[:,0]
xlabels = df_ml.iloc[:,-1]
N = len(df_ml.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars
fig, ax = plt.subplots(figsize=(24,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
rects2 = ax.bar(ind + width, top_3, width, color='#f5c767')
rects3 = ax.bar(ind + 2*width, top_5, width, color='#7a61ba')
ax.set_xticks(ind + width)
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)
ax.set_title('Metrics for ML models | Intra-subject')
ax.legend((rects1[0], rects2[0],rects3[0]),('Acc Test', 'F1 Score Test','Acc Cross Validation'),bbox_to_anchor=(1.13, 1.01))
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)
labelvalue(rects2)
labelvalue(rects3)
plt.savefig('../artifacts/barplot_ml.png',dpi=200, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Transformers Models

# %%
df_trans["label"] = df_trans.model  + "| subjc: " + df_trans.subject.astype(str)  
trans_gb = df_trans.groupby(['model','subject']).mean()
# Out:
#                              acc_test  Precision    Recall  F1_score  \
# model               subject
# Transformer         10       0.259259   0.422970  0.259259  0.266669
#                     11       0.191358   0.273910  0.191358  0.193425
#                     12       0.629630   0.663988  0.629630  0.635009
#                     13       0.135802   0.250332  0.135802  0.081804
#                     14       0.333333   0.422368  0.333333  0.355174
#                     15       0.691358   0.748483  0.691358  0.701178
#                     16       0.185185   0.210915  0.185185  0.110831
#                     17       0.413580   0.471046  0.413580  0.384120
#                     18       0.987654   0.987948  0.987654  0.987650
#                     19       0.228395   0.344593  0.228395  0.254593
# Transformer Pos Enc 10       0.969136   0.969851  0.969136  0.969259
#                     11       0.993827   0.994108  0.993827  0.993880
#                     12       1.000000   1.000000  1.000000  1.000000
#                     13       0.987654   0.987730  0.987654  0.987594
#                     14       0.981481   0.981685  0.981481  0.981496
#                     15       1.000000   1.000000  1.000000  1.000000
#                     16       1.000000   1.000000  1.000000  1.000000
#                     17       0.969136   0.969724  0.969136  0.968876
#                     18       1.000000   1.000000  1.000000  1.000000
#                     19       0.981481   0.981926  0.981481  0.981305
#
#                                   auc     kappa  mathew_coef  acc_train  \
# model               subject
# Transformer         10       0.572183  0.082413     0.099392   0.206173
#                     11       0.466373  0.007715     0.008493   0.207099
#                     12       0.456162  0.489093     0.496880   0.458025
#                     13       0.459507  0.005961     0.008318   0.223457
#                     14       0.388480  0.105201     0.111083   0.239506
#                     15       0.460739  0.583076     0.596790   0.689198
#                     16       0.388480  0.055268     0.076816   0.263272
#                     17       0.490615  0.121224     0.126236   0.276543
#                     18       0.573944  0.982042     0.982096   0.989506
#                     19       0.631690  0.017420     0.018866   0.210494
# Transformer Pos Enc 10       0.563380  0.955254     0.955364   0.987346
#                     11       0.563380  0.991051     0.991111   0.998765
#                     12       0.570423  1.000000     1.000000   0.992593
#                     13       0.595246  0.981981     0.982041   1.000000
#                     14       0.559441  0.973149     0.973208   0.999074
#                     15       0.570423  1.000000     1.000000   0.999074
#                     16       0.566434  1.000000     1.000000   1.000000
#                     17       0.587413  0.954640     0.955067   0.989815
#                     18       0.570423  1.000000     1.000000   0.999383
#                     19       0.577465  0.972974     0.973143   0.988889
#
#                               acc_val
# model               subject
# Transformer         10       0.141975
#                     11       0.123457
#                     12       0.462963
#                     13       0.154321
#                     14       0.296296
#                     15       0.148148
#                     16       0.135802
#                     17       0.308642
#                     18       0.987654
#                     19       0.123457
# Transformer Pos Enc 10       0.981481
#                     11       0.962963
#                     12       0.987654
#                     13       0.987654
#                     14       0.962963
#                     15       0.993827
#                     16       1.000000
#                     17       0.981481
#                     18       1.000000
#                     19       1.000000

# %%
df_trans.head()
# Out:
#    acc_test  Precision    Recall  F1_score       auc     kappa  mathew_coef  \
# 0  1.000000   1.000000  1.000000   1.00000  0.566434  1.000000     1.000000
# 1  1.000000   1.000000  1.000000   1.00000  0.570423  1.000000     1.000000
# 2  1.000000   1.000000  1.000000   1.00000  0.570423  1.000000     1.000000
# 3  1.000000   1.000000  1.000000   1.00000  0.570423  1.000000     1.000000
# 4  0.993827   0.994108  0.993827   0.99388  0.563380  0.991051     0.991111
#
#             model_name                model          dataset  subject  \
# 0  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       16
# 1  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       18
# 2  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       15
# 3  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       12
# 4  Transformer Pos Enc  Transformer Pos Enc  Motor Imaginary       11
#
#    acc_train   acc_val                           label
# 0   1.000000  1.000000  Transformer Pos Enc| subjc: 16
# 1   0.999383  1.000000  Transformer Pos Enc| subjc: 18
# 2   0.999074  0.993827  Transformer Pos Enc| subjc: 15
# 3   0.992593  0.987654  Transformer Pos Enc| subjc: 12
# 4   0.998765  0.962963  Transformer Pos Enc| subjc: 11

# %%
top_1 = df_trans.iloc[:,-3]
top_3 = df_trans.iloc[:,-2]
top_5 = df_trans.iloc[:,0]
xlabels = df_trans.iloc[:,-1]
N = len(df_trans.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars
fig, ax = plt.subplots(figsize=(24,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
rects2 = ax.bar(ind + width, top_3, width, color='#f5c767')
rects3 = ax.bar(ind + 2*width, top_5, width, color='#7a61ba')
ax.set_xticks(ind + width)
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)

ax.set_title('Metrics for Transformer based models | Intra-subject')
ax.legend((rects1[0], rects2[0],rects3[0]),('Acc Train', 'Acc Validation','Acc Test'),bbox_to_anchor=(1.13, 1.01))
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)
labelvalue(rects2)
labelvalue(rects3)
plt.savefig('../artifacts/barplot_trans.png',dpi=200, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Comparing Models

# %%
all_models = pd.concat([
                    df_trans[['model','acc_test']].rename(columns = {'model':'Model', 'acc_test':'Accuracy'}), 
                    df_cnn[['model','acc_test']].rename(columns = {'model':'Model', 'acc_test':'Accuracy'}), 
                    df_ml[['label','Accuracy']].rename(columns = {'label':'Model'})], axis=0, ignore_index=True)
all_models = all_models.sort_values(['Accuracy'], ascending=False)
all_models.to_csv('../artifacts/results_all_models.csv', index=False, header=True)                    
all_models
# Out:
#                    Model  Accuracy
# 0    Transformer Pos Enc  1.000000
# 1    Transformer Pos Enc  1.000000
# 2    Transformer Pos Enc  1.000000
# 3    Transformer Pos Enc  1.000000
# 73  PCA + KNN| subjc: 12  1.000000
# ..                   ...       ...
# 19           Transformer  0.135802
# 57           HopefullNet  0.111111
# 58           HopefullNet  0.111111
# 56           HopefullNet  0.111111
# 59           HopefullNet  0.055556
#
# [120 rows x 2 columns]

# %%
top_1 = all_models.iloc[:,1]
xlabels = all_models.iloc[:,0]
N = len(all_models.iloc[:,0])
ind = np.arange(N)  # the x locations for the groups
width = 0.7      # the width of the bars
fig, ax = plt.subplots(figsize=(30,8))
rects1 = ax.bar(ind, top_1, width, color='#4198d7')
ax.set_xticks(ind )
ax.set_xticklabels(xlabels,fontsize=10, rotation=70)
ax.set_xlabel("models", fontsize=12)
ax.set_ylabel("ACC/%", fontsize=12)
ax.set_title('Metrics for All models | Intra-subject')
# ax.legend(rects1[0],'Accuracy Test')
def labelvalue(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
        str(round(height*100))+'%' ,ha='center', va='bottom',fontsize=7)

labelvalue(rects1)

plt.savefig('../artifacts/barplot_all.png',dpi=200, format='png', bbox_inches='tight')
plt.show()
